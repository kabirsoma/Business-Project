# %% [markdown]
# # Train Models

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np

# do not print warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# the training and test data is loaded 
train_set = pd.read_excel("train_set1.xlsx", index_col = 0)
test_set = pd.read_excel("test_set1.xlsx", index_col = 0)

# %%
train_set.head()
# Out:
#    Real_GDP  Exchange_Rate  Long_Term_Interest_Rates  Current_Account_Balance  \
# 0 -1.074346       1.448440                 -1.182601                 1.933870
# 1  1.559353      -1.187126                  1.266403                -0.716267
# 2 -0.163390      -0.689887                  0.937059                -0.092447
# 3  1.559353      -1.187126                  1.266403                -0.716267
# 4  1.559353      -1.187126                  1.266403                -0.716267
#
#    Unemployment_Rate  Inflation  Population  Corporate_Tax_Rate  \
# 0          -1.142748   1.279434    1.346033           -1.175126
# 1           0.456704  -0.073626   -0.729335            0.305369
# 2           1.713947   0.910418   -1.435507            1.785864
# 3           0.456704  -0.073626   -0.729335            0.305369
# 4           0.456704  -0.073626   -0.729335            0.305369
#
#    Trade_Openess  Administrative_and_support_service_activities  ...  \
# 0       1.339870                                      -0.189838  ...
# 1      -0.482947                                      -0.189838  ...
# 2       0.947761                                      -0.189838  ...
# 3      -0.482947                                      -0.189838  ...
# 4      -0.482947                                      -0.189838  ...
#
#       Spain    Sweden  Switzerland  Taipei, Chinese  Thailand    Turkey  \
# 0 -0.148737 -0.156688    -0.150537        -0.094011  -0.09118 -0.098109
# 1 -0.148737 -0.156688    -0.150537        -0.094011  -0.09118 -0.098109
# 2 -0.148737 -0.156688    -0.150537        -0.094011  -0.09118 -0.098109
# 3 -0.148737 -0.156688    -0.150537        -0.094011  -0.09118 -0.098109
# 4 -0.148737 -0.156688    -0.150537        -0.094011  -0.09118 -0.098109
#
#    United States of America   Uruguay  Venezuela, Bolivarian Republic of  \
# 0                 -0.160107 -0.089733                           -0.09118
# 1                 -0.160107 -0.089733                           -0.09118
# 2                 -0.160107 -0.089733                           -0.09118
# 3                  6.245823 -0.089733                           -0.09118
# 4                 -0.160107 -0.089733                           -0.09118
#
#       FDI
# 0    0.00
# 1    1.59
# 2    0.00
# 3  660.80
# 4    0.00
#
# [5 rows x 95 columns]

# %% [markdown]
# # Create subset

# %%
train_set.Administrative_and_support_service_activities
# Out:
# 0      -0.189838
# 1      -0.189838
# 2      -0.189838
# 3      -0.189838
# 4      -0.189838
# 5      -0.189838
# 6      -0.189838
# 7      -0.189838
# 8      -0.189838
# 9      -0.189838
# 10     -0.189838
# 11     -0.189838
# 12     -0.189838
# 13     -0.189838
# 14      5.267651
# 15     -0.189838
# 16     -0.189838
# 17     -0.189838
# 18     -0.189838
# 19     -0.189838
# 20     -0.189838
# 21     -0.189838
# 22      5.267651
# 23      5.267651
# 24     -0.189838
# 25     -0.189838
# 26     -0.189838
# 27     -0.189838
# 28     -0.189838
# 29     -0.189838
#           ...
# 3851   -0.189838
# 3852   -0.189838
# 3853   -0.189838
# 3854   -0.189838
# 3855   -0.189838
# 3856   -0.189838
# 3857   -0.189838
# 3858   -0.189838
# 3859   -0.189838
# 3860   -0.189838
# 3861   -0.189838
# 3862   -0.189838
# 3863   -0.189838
# 3864   -0.189838
# 3865   -0.189838
# 3866   -0.189838
# 3867   -0.189838
# 3868   -0.189838
# 3869   -0.189838
# 3870   -0.189838
# 3871   -0.189838
# 3872   -0.189838
# 3873   -0.189838
# 3874   -0.189838
# 3875   -0.189838
# 3876   -0.189838
# 3877   -0.189838
# 3878   -0.189838
# 3879   -0.189838
# 3880   -0.189838
# Name: Administrative_and_support_service_activities, Length: 3881, dtype: float64

# %%
model_train = train_set[train_set.Administrative_and_support_service_activities > -0.189]
model_test = test_set[test_set.Administrative_and_support_service_activities > -0.189]

# %%
model_train.head()
# Out:
#     Real_GDP  Exchange_Rate  Long_Term_Interest_Rates  \
# 14  0.630904      -0.458109                  0.039306
# 22 -0.163390      -0.689887                  0.937059
# 23  0.630904      -0.458109                  0.039306
# 30 -0.977965       0.882495                 -1.055125
# 52  0.630904      -0.458109                  0.039306
#
#     Current_Account_Balance  Unemployment_Rate  Inflation  Population  \
# 14                -0.660447          -0.272349  -1.426685    0.008478
# 22                -0.092447           1.713947   0.910418   -1.435507
# 23                -0.660447          -0.272349  -1.426685    0.008478
# 30                -0.489710          -0.718707  -0.688653    0.782246
# 52                -0.660447          -0.272349  -1.426685    0.008478
#
#     Corporate_Tax_Rate  Trade_Openess  \
# 14           -0.434879      -1.364292
# 22            1.785864       0.947761
# 23           -0.434879      -1.364292
# 30           -0.434879      -0.431557
# 52           -0.434879      -1.364292
#
#     Administrative_and_support_service_activities  ...     Spain    Sweden  \
# 14                                       5.267651  ... -0.148737 -0.156688
# 22                                       5.267651  ... -0.148737 -0.156688
# 23                                       5.267651  ... -0.148737 -0.156688
# 30                                       5.267651  ... -0.148737 -0.156688
# 52                                       5.267651  ... -0.148737 -0.156688
#
#     Switzerland  Taipei, Chinese  Thailand    Turkey  \
# 14    -0.150537        -0.094011  -0.09118 -0.098109
# 22    -0.150537        -0.094011  -0.09118 -0.098109
# 23    -0.150537        -0.094011  -0.09118 -0.098109
# 30    -0.150537        -0.094011  -0.09118 -0.098109
# 52    -0.150537        -0.094011  -0.09118 -0.098109
#
#     United States of America   Uruguay  Venezuela, Bolivarian Republic of  \
# 14                 -0.160107 -0.089733                           -0.09118
# 22                 -0.160107 -0.089733                           -0.09118
# 23                 -0.160107 -0.089733                           -0.09118
# 30                 -0.160107 -0.089733                           -0.09118
# 52                 -0.160107 -0.089733                           -0.09118
#
#         FDI
# 14    -0.22
# 22     0.00
# 23 -2580.51
# 30     3.87
# 52     0.00
#
# [5 rows x 95 columns]

# %%
model_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135 entries, 14 to 3826
# Data columns (total 95 columns):
# Real_GDP                                                                   135 non-null float64
# Exchange_Rate                                                              135 non-null float64
# Long_Term_Interest_Rates                                                   135 non-null float64
# Current_Account_Balance                                                    135 non-null float64
# Unemployment_Rate                                                          135 non-null float64
# Inflation                                                                  135 non-null float64
# Population                                                                 135 non-null float64
# Corporate_Tax_Rate                                                         135 non-null float64
# Trade_Openess                                                              135 non-null float64
# Administrative_and_support_service_activities                              135 non-null float64
# Advertising_and_market_research                                            135 non-null float64
# Architectural_and_engineering_activities_technical_testing_and_analysis    135 non-null float64
# Computer_programming_consultancy_and_related_activities                    135 non-null float64
# Construction                                                               135 non-null float64
# Education                                                                  135 non-null float64
# Extraction_of_crude_petroleum_and_natural_gas                              135 non-null float64
# Financial_and_insurance_activities                                         135 non-null float64
# Information_and_communication                                              135 non-null float64
# Legal_and_accounting_activities                                            135 non-null float64
# Management_consultancy_activities                                          135 non-null float64
# Manufacture_of_chemicals_and_chemical_products                             135 non-null float64
# Manufacture_of_computer_electronic_and_optical_products                    135 non-null float64
# Manufacture_of_food_products                                               135 non-null float64
# Manufacture_of_motor_vehicles_trailers_and_semi_trailers                   135 non-null float64
# Mining_and_quarrying                                                       135 non-null float64
# Professional_scientific_and_technical_activities                           135 non-null float64
# Real_estate_activities                                                     135 non-null float64
# Scientific_research_and_development                                        135 non-null float64
# Telecommunications                                                         135 non-null float64
# Transportation_and_storage                                                 135 non-null float64
# Wholesale_and_retail_trade_and_repair_of_motor_vehicles_and_motorcycles    135 non-null float64
# 2014                                                                       135 non-null float64
# 2015                                                                       135 non-null float64
# 2016                                                                       135 non-null float64
# 2017                                                                       135 non-null float64
# Yes                                                                        135 non-null float64
# Australia                                                                  135 non-null float64
# Austria                                                                    135 non-null float64
# Belgium                                                                    135 non-null float64
# Brazil                                                                     135 non-null float64
# Bulgaria                                                                   135 non-null float64
# Canada                                                                     135 non-null float64
# Chile                                                                      135 non-null float64
# China                                                                      135 non-null float64
# Croatia                                                                    135 non-null float64
# Cyprus                                                                     135 non-null float64
# Czech Republic                                                             135 non-null float64
# Denmark                                                                    135 non-null float64
# Egypt                                                                      135 non-null float64
# Estonia                                                                    135 non-null float64
# Finland                                                                    135 non-null float64
# France                                                                     135 non-null float64
# Germany                                                                    135 non-null float64
# Greece                                                                     135 non-null float64
# Hong Kong, China                                                           135 non-null float64
# Hungary                                                                    135 non-null float64
# Iceland                                                                    135 non-null float64
# India                                                                      135 non-null float64
# Indonesia                                                                  135 non-null float64
# Iran, Islamic Republic of                                                  135 non-null float64
# Ireland                                                                    135 non-null float64
# Israel                                                                     135 non-null float64
# Italy                                                                      135 non-null float64
# Japan                                                                      135 non-null float64
# Korea, Republic of                                                         135 non-null float64
# Latvia                                                                     135 non-null float64
# Lithuania                                                                  135 non-null float64
# Luxembourg                                                                 135 non-null float64
# Malaysia                                                                   135 non-null float64
# Malta                                                                      135 non-null float64
# Mexico                                                                     135 non-null float64
# Morocco                                                                    135 non-null float64
# Netherlands                                                                135 non-null float64
# New Zealand                                                                135 non-null float64
# Nigeria                                                                    135 non-null float64
# Norway                                                                     135 non-null float64
# Philippines                                                                135 non-null float64
# Poland                                                                     135 non-null float64
# Portugal                                                                   135 non-null float64
# Romania                                                                    135 non-null float64
# Russian Federation                                                         135 non-null float64
# Singapore                                                                  135 non-null float64
# Slovakia                                                                   135 non-null float64
# Slovenia                                                                   135 non-null float64
# South Africa                                                               135 non-null float64
# Spain                                                                      135 non-null float64
# Sweden                                                                     135 non-null float64
# Switzerland                                                                135 non-null float64
# Taipei, Chinese                                                            135 non-null float64
# Thailand                                                                   135 non-null float64
# Turkey                                                                     135 non-null float64
# United States of America                                                   135 non-null float64
# Uruguay                                                                    135 non-null float64
# Venezuela, Bolivarian Republic of                                          135 non-null float64
# FDI                                                                        135 non-null float64
# dtypes: float64(95)
# memory usage: 101.2 KB

# %%
for col_name in ["Advertising_and_market_research", "Financial_and_insurance_activities",
                 "Architectural_and_engineering_activities_technical_testing_and_analysis", 
                 "Computer_programming_consultancy_and_related_activities","Construction", 
                 "Education","Extraction_of_crude_petroleum_and_natural_gas","Information_and_communication",
                 "Legal_and_accounting_activities","Management_consultancy_activities",
                 "Manufacture_of_chemicals_and_chemical_products", "Manufacture_of_computer_electronic_and_optical_products",
                 "Manufacture_of_food_products","Manufacture_of_motor_vehicles_trailers_and_semi_trailers",
                 "Mining_and_quarrying","Professional_scientific_and_technical_activities","Real_estate_activities",
                 "Scientific_research_and_development","Telecommunications","Transportation_and_storage",
                 "Wholesale_and_retail_trade_and_repair_of_motor_vehicles_and_motorcycles"]:
                 
    
    del model_train[col_name]
    del model_test[col_name]

# %%
model_train.head()
# Out:
#     Real_GDP  Exchange_Rate  Long_Term_Interest_Rates  \
# 14  0.630904      -0.458109                  0.039306
# 22 -0.163390      -0.689887                  0.937059
# 23  0.630904      -0.458109                  0.039306
# 30 -0.977965       0.882495                 -1.055125
# 52  0.630904      -0.458109                  0.039306
#
#     Current_Account_Balance  Unemployment_Rate  Inflation  Population  \
# 14                -0.660447          -0.272349  -1.426685    0.008478
# 22                -0.092447           1.713947   0.910418   -1.435507
# 23                -0.660447          -0.272349  -1.426685    0.008478
# 30                -0.489710          -0.718707  -0.688653    0.782246
# 52                -0.660447          -0.272349  -1.426685    0.008478
#
#     Corporate_Tax_Rate  Trade_Openess  \
# 14           -0.434879      -1.364292
# 22            1.785864       0.947761
# 23           -0.434879      -1.364292
# 30           -0.434879      -0.431557
# 52           -0.434879      -1.364292
#
#     Administrative_and_support_service_activities  ...     Spain    Sweden  \
# 14                                       5.267651  ... -0.148737 -0.156688
# 22                                       5.267651  ... -0.148737 -0.156688
# 23                                       5.267651  ... -0.148737 -0.156688
# 30                                       5.267651  ... -0.148737 -0.156688
# 52                                       5.267651  ... -0.148737 -0.156688
#
#     Switzerland  Taipei, Chinese  Thailand    Turkey  \
# 14    -0.150537        -0.094011  -0.09118 -0.098109
# 22    -0.150537        -0.094011  -0.09118 -0.098109
# 23    -0.150537        -0.094011  -0.09118 -0.098109
# 30    -0.150537        -0.094011  -0.09118 -0.098109
# 52    -0.150537        -0.094011  -0.09118 -0.098109
#
#     United States of America   Uruguay  Venezuela, Bolivarian Republic of  \
# 14                 -0.160107 -0.089733                           -0.09118
# 22                 -0.160107 -0.089733                           -0.09118
# 23                 -0.160107 -0.089733                           -0.09118
# 30                 -0.160107 -0.089733                           -0.09118
# 52                 -0.160107 -0.089733                           -0.09118
#
#         FDI
# 14    -0.22
# 22     0.00
# 23 -2580.51
# 30     3.87
# 52     0.00
#
# [5 rows x 74 columns]

# %%
# drop labels for training set, but keep all others
Xtrain = model_train.drop("FDI", axis=1)

ytrain = model_train["FDI"].copy()

# %% [markdown]
# # Baseline

# %%
mean_FDI = ytrain.mean()
mean_FDI
# Out:
# 13.350740740740735

# %%
from sklearn.metrics import mean_squared_error

# yhat will have the same number of rows as ytrain, 
# each cell will be filled with the same value, median_price
yhat = np.full((ytrain.shape[0], 1), mean_FDI)

baseline_mse = mean_squared_error(ytrain, yhat)

# take square root
baseline_rmse = np.sqrt(baseline_mse)

baseline_rmse
# Out:
# 303.2189454274221

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import GridSearchCV
import time
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(random_state=7)

# specify the hyperparameters and their values
# 3 x 3 x 3 x 3 x 3 = 243 combinations in the grid 

param_grid = {
    'n_estimators': [5, 10, 20],
    'max_depth': [1, 2, 3],
    'min_samples_split': [1.0, 2, 3],
    'max_features': [0.1, 0.2, "auto"], 
    'min_samples_leaf': [1, 2, 3]
    
    
    
    
    
    

    
}

# we'll use 10-fold cross-validation
grid_search = GridSearchCV(rf_reg, param_grid, cv=10,
                           scoring='neg_mean_squared_error', 
                           return_train_score=True)

start = time.time()
grid_search.fit(Xtrain, ytrain)
end = time.time() - start
print(f"Took {end} seconds")
# Out:
# Took 50.67630195617676 seconds
# C:\Intel\Python\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=3,
#                       max_features=0.2, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=7, verbose=0,
#                       warm_start=False)

# %%
np.sqrt(-grid_search.best_score_)
# Out:
# 299.1547561441048

# %%
val_scores = grid_search.cv_results_["mean_test_score"]
train_scores = grid_search.cv_results_["mean_train_score"]
params = [str(x) for x in grid_search.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 299.1547561441048 256.4099631672297 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 300.8311723267433 276.39900323012984 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 300.97990158808807 260.11077625972405 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 300.98576727189567 277.2707153046349 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 302.070965542772 269.1335592513498 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 302.0710038378582 269.7170705938916 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 302.24309170286625 244.05376900014363 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 303.26233155423307 260.16558909735465 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 303.26233155423307 260.16558909735465 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 303.7631089254903 246.68717672747948 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 303.9501054138316 263.5765625144497 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 303.9501054138316 263.5765625144497 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 304.14470303770815 267.76839314600494 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 304.3565143638005 266.0425836786888 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 304.3565143638005 266.0425836786888 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 304.37327261945876 281.22338224376983 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 304.37327261945876 281.22338224376983 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 304.4253741050454 268.6539899336897 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 304.4253741050454 268.6539899336897 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 304.52725969273047 282.3069684467416 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 304.52725969273047 282.3069684467416 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 304.9593494950789 265.86253391306246 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 304.9593494950789 265.86253391306246 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 304.9827161214534 280.5151849885907 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 305.19404762542877 284.16018743401963 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 305.19404762542877 284.16018743401963 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 305.329757829674 262.1923857206197 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 305.329757829674 262.1923857206197 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 305.4052547515637 280.98183799711154 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 305.4562374507555 272.15248370507265 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 305.4562374507555 272.15248370507265 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 305.4727522637818 277.59131027979555 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 305.5883222086262 281.4901325812893 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 305.5883222086262 281.4901325812893 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 305.61296943246714 276.16477660100816 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 305.7520058526596 263.17992147720366 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 305.81101467638433 270.4997821914165 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 305.87104334357156 286.2715130229248 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 305.87104334357156 286.2715130229248 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 306.0290559300031 270.5475174673276 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 306.1550925251541 283.78354751689284 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 306.1550925251541 283.78354751689284 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 306.8619084725078 298.6251001412913 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 306.8619084725078 298.6251001412913 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 306.8782971993609 297.60778035364535 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 306.8782971993609 297.60778035364535 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 306.90414201067944 292.7123464094552 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 306.90414201067944 292.7123464094552 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 306.9978502941255 303.078984268335 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.00326471610913 303.11167297144027 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 307.01027251214106 273.1949014898211 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.01345573751564 303.123529390006 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 5}
# 307.0192239205412 297.53106668073343 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 307.0192239205412 297.53106668073343 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 307.07201949516815 294.21889885958643 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 307.07201949516815 294.21889885958643 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 307.2645024812522 286.96668414923795 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 307.2659773554623 276.49743864052317 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 307.2659773554623 276.49743864052317 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 307.3989285730582 295.6334727236452 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 307.3989285730582 295.6334727236452 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 307.47279266831777 287.18925719195255 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 307.63755778179484 274.51777946568365 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 307.63755778179484 274.51777946568365 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 307.6781086738885 290.0152780817469 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 307.6781086738885 290.0152780817469 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 307.7136491257932 292.75825351599974 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 307.7136491257932 292.75825351599974 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 307.86149698318064 296.6887314080269 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 307.86149698318064 296.6887314080269 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 307.96466534355847 296.778511843621 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 307.96466534355847 296.778511843621 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 308.15252572167446 293.08015587600363 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 308.15252572167446 293.08015587600363 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 308.15649373320707 296.3006627631384 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 308.15649373320707 296.3006627631384 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 308.23813131418166 285.3840436964126 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 308.23813131418166 285.3840436964126 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 308.2460284219285 289.5176167255939 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 308.2460284219285 289.5176167255939 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 308.2910026603587 298.2607420364628 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 308.2910026603587 298.2607420364628 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 308.2910026603587 298.2607420364628 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 308.2910026603587 298.2607420364628 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 308.3202853174082 289.0086658715202 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 308.3202853174082 289.0086658715202 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 308.33503561134603 292.5161734367576 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 308.33503561134603 292.5161734367576 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 308.33776797914066 295.84721719588066 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 308.33776797914066 295.84721719588066 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 308.3894550808249 296.1791949353908 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 308.3894550808249 296.1791949353908 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 308.4127836914236 295.60525461199524 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 308.4127836914236 295.60525461199524 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 308.4595690695916 289.02472042006946 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 308.4595690695916 289.02472042006946 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 308.47995731216423 291.3021016063835 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 308.47995731216423 291.3021016063835 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 308.51639480152863 296.8652372912463 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 308.51639480152863 296.8652372912463 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 308.5417314013135 268.8894785853055 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 308.5968113806592 286.94258494887634 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 308.5968113806592 286.94258494887634 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 308.63690974864915 295.7081065064666 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 308.63690974864915 295.7081065064666 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 308.784329605228 294.03366200090454 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 308.784329605228 294.03366200090454 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 308.8604652024726 289.4634717824411 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 308.86455820651645 283.6723207718437 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 308.91470814782934 294.19501800165153 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 308.91470814782934 294.19501800165153 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 309.16509835757176 289.8774669605315 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 309.2836186744849 290.0683849599648 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 309.2836186744849 290.0683849599648 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 309.38754491337653 294.6208039223695 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 309.38754491337653 294.6208039223695 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 309.41248399499574 291.1174508110064 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 309.41248399499574 291.1174508110064 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 309.4163992915152 184.1473977608001 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 309.45502974614027 289.4898602779719 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# 309.45502974614027 289.4898602779719 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5}
# 309.6039714976102 294.94440396387245 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 309.6039714976102 294.94440396387245 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 309.8328272716245 288.28849418205965 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 309.8328272716245 288.28849418205965 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 309.9080693556203 284.39776185122133 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 309.9625900106098 295.08601578754104 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 309.9625900106098 295.08601578754104 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 309.9865385032897 238.03806383101528 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 309.9865385032897 238.03806383101528 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 310.20629193438543 294.97542144577943 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 310.20629193438543 294.97542144577943 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 310.4728270435479 189.85886436810642 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 310.91958441328967 241.40932858998804 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 310.91958441328967 241.40932858998804 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 311.07911715849957 230.13477218236673 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 311.07911715849957 230.13477218236673 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 311.1312206546435 267.9085697749529 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 311.1312206546435 267.9085697749529 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 311.9810984991904 232.70370076274384 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 311.9810984991904 232.70370076274384 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 312.0152352224075 265.6880870068958 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 312.0152352224075 265.6880870068958 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 312.2219063343111 267.4381281895587 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 312.2219063343111 267.4381281895587 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 312.723184629386 201.219969274766 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 314.67441598782574 265.22779977291043 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 314.67441598782574 265.22779977291043 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 314.8721858379834 163.82112463869808 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 315.94618529637415 153.71045409058868 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 317.8876761273722 266.6904904860966 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 317.8876761273722 266.6904904860966 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 318.24899172530627 246.87897344168212 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 318.24899172530627 246.87897344168212 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 318.7349092791618 268.5370058911397 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 318.7349092791618 268.5370058911397 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 318.82940983222636 237.90048747530832 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 5}
# 318.82940983222636 237.90048747530832 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
# 319.1688249031152 191.9615805349969 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 319.74463008347226 174.812212488143 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 325.7973146195876 160.98635106815078 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 329.58349471692554 182.98427000983423 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 329.7152696407186 204.94199531296417 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 5}
# 339.75362315256876 197.18166849952593 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
# 349.8124955738857 175.4691167641281 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}

# %%
# put them into a separate variable for convenience
feature_importances = grid_search.best_estimator_.feature_importances_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# United States of America: 0.2058714595436077
# Belgium: 0.16059274532698692
# Canada: 0.08306142145828493
# Luxembourg: 0.06526354644014039
# Long_Term_Interest_Rates: 0.06330552790954022
# Germany: 0.061654572628444114
# Inflation: 0.05779579072416223
# Current_Account_Balance: 0.05090448016557557
# 2017: 0.050755788721606174
# France: 0.043796337121608714
# Unemployment_Rate: 0.038054755804864386
# Trade_Openess: 0.03744347978035051
# Netherlands: 0.020461445704858715
# Yes: 0.01675047813875922
# Population: 0.014906617747260126
# Corporate_Tax_Rate: 0.0085167079365225
# 2015: 0.007245283273045566
# 2014: 0.005990976597734553
# Italy: 0.002770291022397517
# Lithuania: 0.0018760843366891788
# Real_GDP: 0.0011122183044063262
# Russian Federation: 0.0009990153752205179
# Switzerland: 0.0005885224780364727
# Latvia: 0.00027115626059352543
# Croatia: 1.1297199303953619e-05
# Venezuela, Bolivarian Republic of: 0.0
# Uruguay: 0.0
# Turkey: 0.0
# Thailand: 0.0
# Taipei, Chinese: 0.0
# Sweden: 0.0
# Spain: 0.0
# South Africa: 0.0
# Slovenia: 0.0
# Slovakia: 0.0
# Singapore: 0.0
# Romania: 0.0
# Portugal: 0.0
# Poland: 0.0
# Philippines: 0.0
# Norway: 0.0
# Nigeria: 0.0
# New Zealand: 0.0
# Morocco: 0.0
# Mexico: 0.0
# Malta: 0.0
# Malaysia: 0.0
# Korea, Republic of: 0.0
# Japan: 0.0
# Israel: 0.0
# Ireland: 0.0
# Iran, Islamic Republic of: 0.0
# Indonesia: 0.0
# India: 0.0
# Iceland: 0.0
# Hungary: 0.0
# Hong Kong, China: 0.0
# Greece: 0.0
# Finland: 0.0
# Exchange_Rate: 0.0
# Estonia: 0.0
# Egypt: 0.0
# Denmark: 0.0
# Czech Republic: 0.0
# Cyprus: 0.0
# China: 0.0
# Chile: 0.0
# Bulgaria: 0.0
# Brazil: 0.0
# Austria: 0.0
# Australia: 0.0
# Administrative_and_support_service_activities: 0.0
# 2016: 0.0

# %% [markdown]
# # Test Evaluation

# %%
# drop labels for training set, but keep all others
Xtest = model_test.drop("FDI", axis=1)
ytest = model_test["FDI"].copy()

best_model = grid_search.best_estimator_

yhat = best_model.predict(Xtest)

final_mse = mean_squared_error(ytest, yhat)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 96.43338621216506

# %% [markdown]
# # Reduction in RMSE rate

# %%
100*(baseline_rmse - final_rmse)/baseline_rmse
# Out:
# 68.19678068722551

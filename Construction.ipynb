# %% [markdown]
# # Train Models

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np

# do not print warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# the training and test data is loaded 
train_set = pd.read_excel("train_set1.xlsx", index_col = 0)
test_set = pd.read_excel("test_set1.xlsx", index_col = 0)

# %% [markdown]
# # Create subset

# %%
train_set.Construction
# Out:
# 0      -0.247492
# 1      -0.247492
# 2      -0.247492
# 3      -0.247492
# 4      -0.247492
# 5      -0.247492
# 6      -0.247492
# 7       4.040531
# 8      -0.247492
# 9      -0.247492
# 10     -0.247492
# 11     -0.247492
# 12     -0.247492
# 13     -0.247492
# 14     -0.247492
# 15     -0.247492
# 16     -0.247492
# 17      4.040531
# 18     -0.247492
# 19     -0.247492
# 20     -0.247492
# 21     -0.247492
# 22     -0.247492
# 23     -0.247492
# 24     -0.247492
# 25     -0.247492
# 26     -0.247492
# 27     -0.247492
# 28     -0.247492
# 29     -0.247492
#           ...
# 3851   -0.247492
# 3852   -0.247492
# 3853   -0.247492
# 3854   -0.247492
# 3855   -0.247492
# 3856   -0.247492
# 3857   -0.247492
# 3858   -0.247492
# 3859   -0.247492
# 3860   -0.247492
# 3861   -0.247492
# 3862   -0.247492
# 3863   -0.247492
# 3864   -0.247492
# 3865   -0.247492
# 3866   -0.247492
# 3867   -0.247492
# 3868   -0.247492
# 3869   -0.247492
# 3870   -0.247492
# 3871   -0.247492
# 3872   -0.247492
# 3873   -0.247492
# 3874   -0.247492
# 3875   -0.247492
# 3876   -0.247492
# 3877   -0.247492
# 3878   -0.247492
# 3879    4.040531
# 3880   -0.247492
# Name: Construction, Length: 3881, dtype: float64

# %%
model_train = train_set[train_set.Construction > -0.247]
model_test = test_set[test_set.Construction > -0.247]

# %%
model_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 224 entries, 7 to 3879
# Data columns (total 95 columns):
# Real_GDP                                                                   224 non-null float64
# Exchange_Rate                                                              224 non-null float64
# Long_Term_Interest_Rates                                                   224 non-null float64
# Current_Account_Balance                                                    224 non-null float64
# Unemployment_Rate                                                          224 non-null float64
# Inflation                                                                  224 non-null float64
# Population                                                                 224 non-null float64
# Corporate_Tax_Rate                                                         224 non-null float64
# Trade_Openess                                                              224 non-null float64
# Administrative_and_support_service_activities                              224 non-null float64
# Advertising_and_market_research                                            224 non-null float64
# Architectural_and_engineering_activities_technical_testing_and_analysis    224 non-null float64
# Computer_programming_consultancy_and_related_activities                    224 non-null float64
# Construction                                                               224 non-null float64
# Education                                                                  224 non-null float64
# Extraction_of_crude_petroleum_and_natural_gas                              224 non-null float64
# Financial_and_insurance_activities                                         224 non-null float64
# Information_and_communication                                              224 non-null float64
# Legal_and_accounting_activities                                            224 non-null float64
# Management_consultancy_activities                                          224 non-null float64
# Manufacture_of_chemicals_and_chemical_products                             224 non-null float64
# Manufacture_of_computer_electronic_and_optical_products                    224 non-null float64
# Manufacture_of_food_products                                               224 non-null float64
# Manufacture_of_motor_vehicles_trailers_and_semi_trailers                   224 non-null float64
# Mining_and_quarrying                                                       224 non-null float64
# Professional_scientific_and_technical_activities                           224 non-null float64
# Real_estate_activities                                                     224 non-null float64
# Scientific_research_and_development                                        224 non-null float64
# Telecommunications                                                         224 non-null float64
# Transportation_and_storage                                                 224 non-null float64
# Wholesale_and_retail_trade_and_repair_of_motor_vehicles_and_motorcycles    224 non-null float64
# 2014                                                                       224 non-null float64
# 2015                                                                       224 non-null float64
# 2016                                                                       224 non-null float64
# 2017                                                                       224 non-null float64
# Yes                                                                        224 non-null float64
# Australia                                                                  224 non-null float64
# Austria                                                                    224 non-null float64
# Belgium                                                                    224 non-null float64
# Brazil                                                                     224 non-null float64
# Bulgaria                                                                   224 non-null float64
# Canada                                                                     224 non-null float64
# Chile                                                                      224 non-null float64
# China                                                                      224 non-null float64
# Croatia                                                                    224 non-null float64
# Cyprus                                                                     224 non-null float64
# Czech Republic                                                             224 non-null float64
# Denmark                                                                    224 non-null float64
# Egypt                                                                      224 non-null float64
# Estonia                                                                    224 non-null float64
# Finland                                                                    224 non-null float64
# France                                                                     224 non-null float64
# Germany                                                                    224 non-null float64
# Greece                                                                     224 non-null float64
# Hong Kong, China                                                           224 non-null float64
# Hungary                                                                    224 non-null float64
# Iceland                                                                    224 non-null float64
# India                                                                      224 non-null float64
# Indonesia                                                                  224 non-null float64
# Iran, Islamic Republic of                                                  224 non-null float64
# Ireland                                                                    224 non-null float64
# Israel                                                                     224 non-null float64
# Italy                                                                      224 non-null float64
# Japan                                                                      224 non-null float64
# Korea, Republic of                                                         224 non-null float64
# Latvia                                                                     224 non-null float64
# Lithuania                                                                  224 non-null float64
# Luxembourg                                                                 224 non-null float64
# Malaysia                                                                   224 non-null float64
# Malta                                                                      224 non-null float64
# Mexico                                                                     224 non-null float64
# Morocco                                                                    224 non-null float64
# Netherlands                                                                224 non-null float64
# New Zealand                                                                224 non-null float64
# Nigeria                                                                    224 non-null float64
# Norway                                                                     224 non-null float64
# Philippines                                                                224 non-null float64
# Poland                                                                     224 non-null float64
# Portugal                                                                   224 non-null float64
# Romania                                                                    224 non-null float64
# Russian Federation                                                         224 non-null float64
# Singapore                                                                  224 non-null float64
# Slovakia                                                                   224 non-null float64
# Slovenia                                                                   224 non-null float64
# South Africa                                                               224 non-null float64
# Spain                                                                      224 non-null float64
# Sweden                                                                     224 non-null float64
# Switzerland                                                                224 non-null float64
# Taipei, Chinese                                                            224 non-null float64
# Thailand                                                                   224 non-null float64
# Turkey                                                                     224 non-null float64
# United States of America                                                   224 non-null float64
# Uruguay                                                                    224 non-null float64
# Venezuela, Bolivarian Republic of                                          224 non-null float64
# FDI                                                                        224 non-null float64
# dtypes: float64(95)
# memory usage: 168.0 KB

# %%
for col_name in ["Administrative_and_support_service_activities","Advertising_and_market_research",
                 "Architectural_and_engineering_activities_technical_testing_and_analysis", 
                 "Computer_programming_consultancy_and_related_activities","Management_consultancy_activities", 
                 "Education","Extraction_of_crude_petroleum_and_natural_gas","Information_and_communication",
                 "Legal_and_accounting_activities","Professional_scientific_and_technical_activities",
                 "Manufacture_of_chemicals_and_chemical_products", "Manufacture_of_computer_electronic_and_optical_products",
                 "Manufacture_of_food_products","Manufacture_of_motor_vehicles_trailers_and_semi_trailers",
                 "Mining_and_quarrying","Financial_and_insurance_activities","Real_estate_activities",
                 "Scientific_research_and_development","Telecommunications","Transportation_and_storage",
                 "Wholesale_and_retail_trade_and_repair_of_motor_vehicles_and_motorcycles"]:
                 
    
    del model_train[col_name]
    del model_test[col_name]

# %%
model_train.head()
# Out:
#      Real_GDP  Exchange_Rate  Long_Term_Interest_Rates  \
# 7   -0.977965       0.882495                 -1.055125
# 17  -1.074346       1.448440                 -1.182601
# 32  -1.074346       1.448440                 -1.182601
# 46  -0.977965       0.882495                 -1.055125
# 110 -0.163390      -0.689887                  0.937059
#
#      Current_Account_Balance  Unemployment_Rate  Inflation  Population  \
# 7                  -0.489710          -0.718707  -0.688653    0.782246
# 17                  1.933870          -1.142748   1.279434    1.346033
# 32                  1.933870          -1.142748   1.279434    1.346033
# 46                 -0.489710          -0.718707  -0.688653    0.782246
# 110                -0.092447           1.713947   0.910418   -1.435507
#
#      Corporate_Tax_Rate  Trade_Openess  Construction  ...     Spain    Sweden  \
# 7             -0.434879      -0.431557      4.040531  ... -0.148737 -0.156688
# 17            -1.175126       1.339870      4.040531  ...  6.723272 -0.156688
# 32            -1.175126       1.339870      4.040531  ... -0.148737 -0.156688
# 46            -0.434879      -0.431557      4.040531  ... -0.148737 -0.156688
# 110            1.785864       0.947761      4.040531  ... -0.148737 -0.156688
#
#      Switzerland  Taipei, Chinese  Thailand    Turkey  \
# 7      -0.150537        -0.094011  -0.09118 -0.098109
# 17     -0.150537        -0.094011  -0.09118 -0.098109
# 32     -0.150537        10.637061  -0.09118 -0.098109
# 46     -0.150537        -0.094011  -0.09118 -0.098109
# 110    -0.150537        -0.094011  -0.09118 -0.098109
#
#      United States of America   Uruguay  Venezuela, Bolivarian Republic of  \
# 7                   -0.160107 -0.089733                           -0.09118
# 17                  -0.160107 -0.089733                           -0.09118
# 32                  -0.160107 -0.089733                           -0.09118
# 46                  -0.160107 -0.089733                           -0.09118
# 110                 -0.160107 -0.089733                           -0.09118
#
#      FDI
# 7    0.0
# 17   0.0
# 32   0.0
# 46   0.0
# 110  0.0
#
# [5 rows x 74 columns]

# %%
# drop labels for training set, but keep all others
Xtrain = model_train.drop("FDI", axis=1)

ytrain = model_train["FDI"].copy()

# %% [markdown]
# # Baseline

# %%
mean_FDI = ytrain.mean()
mean_FDI
# Out:
# -1.7160714285714285

# %%
from sklearn.metrics import mean_squared_error

# yhat will have the same number of rows as ytrain, 
# each cell will be filled with the same value, median_price
yhat = np.full((ytrain.shape[0], 1), mean_FDI)

baseline_mse = mean_squared_error(ytrain, yhat)

# take square root
baseline_rmse = np.sqrt(baseline_mse)

baseline_rmse
# Out:
# 30.32013287867671

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import GridSearchCV
import time
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(random_state=7)

# specify the hyperparameters and their values
# 3 x 3 x 3 x 3 x 3 = 243 combinations in the grid 

param_grid = {
    'n_estimators': [10, 20, 30],
    'max_depth': [1, 2, 3],
    'min_samples_split': [1.0, 2, 3],
    'max_features': [0.1, 0.2, "auto"], 
    'min_samples_leaf': [1, 2, 3]
    
    
    
    
    
    

    
}

# we'll use 10-fold cross-validation
grid_search = GridSearchCV(rf_reg, param_grid, cv=10,
                           scoring='neg_mean_squared_error', 
                           return_train_score=True)

start = time.time()
grid_search.fit(Xtrain, ytrain)
end = time.time() - start
print(f"Took {end} seconds")
# Out:
# Took 76.83650803565979 seconds
# C:\Intel\Python\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=20,
#                       n_jobs=None, oob_score=False, random_state=7, verbose=0,
#                       warm_start=False)

# %%
np.sqrt(-grid_search.best_score_)
# Out:
# 25.15494388741067

# %%
val_scores = grid_search.cv_results_["mean_test_score"]
train_scores = grid_search.cv_results_["mean_train_score"]
params = [str(x) for x in grid_search.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 25.15494388741067 18.838741858440287 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 25.434629102438326 16.862058064679406 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 25.473714269881565 18.842997036156213 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 25.54758550879772 19.50323832024712 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 25.68043367889787 17.706660620498784 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 25.837792113321935 16.716333037177105 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 27.237114927679748 20.972127263335953 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 27.280787588062577 20.147069053831913 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 27.289426977032164 19.018011070695575 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 27.584671971010394 18.734255372016786 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 27.748634750205422 20.044913716887997 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 27.76401219585393 20.05721180785747 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 28.052598833988064 25.042602702213646 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 28.052598833988064 25.042602702213646 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 28.118889365728577 25.060508568859834 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 28.118889365728577 25.060508568859834 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 28.231219188170908 25.239275643032016 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 28.231219188170908 25.239275643032016 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 28.32418377543797 24.161310393180372 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 28.678485069952465 24.235933331430243 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 28.728370709869395 23.71984211098189 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 28.81137802942536 26.547214417337063 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 28.840063868034846 24.676962934523175 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 28.874872737233176 25.071926722697864 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 28.925176413640237 23.83961943767831 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 29.280896629412226 26.95230276811354 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 29.465906965053534 25.617148856930882 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 29.465906965053534 25.617148856930882 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 29.49824496445433 26.749834287018544 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 29.626621979866496 25.55254545858383 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 29.626621979866496 25.55254545858383 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 29.68042387972431 27.194178094394847 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 29.736353442404297 27.769213843799122 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 29.736353442404297 27.769213843799122 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 29.773020966392174 27.79628204673374 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 29.819078306159767 27.08780329961525 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 29.834534055986136 28.239322251398125 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 29.834534055986136 28.239322251398125 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 29.89010348190849 27.392988110523664 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 29.89643301096696 27.94817682653203 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 29.92470292677808 27.293195374657873 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 29.95893897986849 26.97240026127345 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 29.96288164515003 28.051145129545088 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 29.96831450401598 28.507968558144416 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 29.96831450401598 28.507968558144416 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 29.98484584831497 27.75131692926499 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 29.98484584831497 27.75131692926499 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 29.990074066125135 28.313048824997782 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 29.990074066125135 28.313048824997782 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 30.025145323799062 27.153140843098086 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 30.056201058051784 23.250001478831642 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 30.056201058051784 23.250001478831642 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 30.06521683247844 29.383564717715988 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 30.06521683247844 29.383564717715988 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 30.06705619524281 29.38341413720995 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 30.06705619524281 29.38341413720995 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 30.06909955020121 29.364780907835712 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 30.06909955020121 29.364780907835712 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 30.070601693861118 27.461653122719355 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 30.11857620070327 29.3498523881271 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 30.11857620070327 29.3498523881271 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# 30.127155228276752 27.337313419204627 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 30.1504334494217 28.045670349747322 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 30.16698191678908 28.484502738490487 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 30.16698191678908 28.484502738490487 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 30.174051468371832 28.254600586719665 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 30.182177336701013 28.706037737432705 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 30.182177336701013 28.706037737432705 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 30.190263148208707 28.598144122425253 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 30.190263148208707 28.598144122425253 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 30.231201003151877 28.158070937445913 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 30.27108779628832 28.766732579569258 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.27108779628832 28.766732579569258 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.290890319648916 26.673753739303436 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.290890319648916 26.673753739303436 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.299351448175642 23.31407162898643 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.299351448175642 23.31407162898643 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.299660024257204 29.58854077856201 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 30.299660024257204 29.58854077856201 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 30.30150291157894 29.719218962825764 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 30.30150291157894 29.719218962825764 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 30.30422556450673 28.556867086165013 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.30422556450673 28.556867086165013 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.30781795776743 29.709148646242927 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 30.30781795776743 29.709148646242927 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 30.31521574153905 27.558093333786065 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 10}
# 30.319925416731543 26.711122978960955 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.319925416731543 26.711122978960955 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.321376510905306 25.947511770927207 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 30.321376510905306 25.947511770927207 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 30.322239721327474 27.679463290526797 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.322239721327474 27.679463290526797 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.347730227401026 29.590965813386852 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 30.347730227401026 29.590965813386852 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 30.384647073850516 29.570733772758683 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 20}
# 30.384647073850516 29.570733772758683 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
# 30.39430853970459 22.666727207686467 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20}
# 30.39430853970459 22.666727207686467 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# 30.42684500311713 29.44481963905189 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.42684500311713 29.44481963905189 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.431299804145674 29.81099280320495 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.431299804145674 29.81099280320495 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.44996389475358 29.79912772790047 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 30}
# 30.44996389475358 29.79912772790047 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 30.45550213505753 28.709650421652128 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.45550213505753 28.709650421652128 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.462407477130814 29.427624169809732 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.462407477130814 29.427624169809732 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.4956020035258 30.315330081647033 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 20}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.510422496596657 30.31433279108439 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 30}
# 30.514021195134397 29.65180653915953 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.514021195134397 29.65180653915953 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.518282187984024 30.325952419449635 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1.0, 'n_estimators': 10}
# 30.54219790430564 23.206964300198088 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 30.54219790430564 23.206964300198088 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 30.55799567968418 29.55953161496311 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.55799567968418 29.55953161496311 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.567302604027777 26.257358898708755 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.567302604027777 26.257358898708755 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.5825707171422 26.066122443586227 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.5825707171422 26.066122443586227 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.583352038121042 29.897546920648487 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.583352038121042 29.897546920648487 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.584302958244155 26.311070757974388 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.584302958244155 26.311070757974388 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.58905589686712 29.947236787534454 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.58905589686712 29.947236787534454 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.60420711255009 29.778739436437235 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.60420711255009 29.778739436437235 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.607232845729392 29.674503650737982 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 30.607232845729392 29.674503650737982 {'max_depth': 1, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 30.608108729250162 29.532864472984578 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.608108729250162 29.532864472984578 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.616258986727477 29.66132633318054 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 30.616258986727477 29.66132633318054 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 30.63013440610884 26.12594904474195 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.63013440610884 26.12594904474195 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.63506779869104 29.339430880996147 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 30.63506779869104 29.339430880996147 {'max_depth': 2, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 30.637188102286885 29.815821207135052 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.637188102286885 29.815821207135052 {'max_depth': 1, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.648543226404804 29.3053894297811 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 30.648543226404804 29.3053894297811 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 30.64866871388107 29.328505576104774 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 30.64866871388107 29.328505576104774 {'max_depth': 3, 'max_features': 0.1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 30.6568349715398 29.51253945027003 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.6568349715398 29.51253945027003 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.665523501858665 29.240441582223106 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 30.665523501858665 29.240441582223106 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 30.669110229170805 22.789607876536905 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 30}
# 30.669110229170805 22.789607876536905 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 30.66927001504508 29.450697620512273 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 20}
# 30.66927001504508 29.450697620512273 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 30.730003081603844 29.5582780542923 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.730003081603844 29.5582780542923 {'max_depth': 2, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.735883600742977 29.479181204857788 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 30}
# 30.735883600742977 29.479181204857788 {'max_depth': 3, 'max_features': 0.2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 30}
# 30.99682691717033 22.660850670672 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# 30.99682691717033 22.660850670672 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 31.147143423931396 27.195213504550868 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 31.147143423931396 27.195213504550868 {'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 31.4210400536959 26.657516800633292 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 31.4210400536959 26.657516800633292 {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}
# 31.42726753509242 26.845019155281157 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 10}
# 31.42726753509242 26.845019155281157 {'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10}

# %%
# put them into a separate variable for convenience
feature_importances = grid_search.best_estimator_.feature_importances_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# Ireland: 0.4245837739269698
# France: 0.10421574493065211
# Real_GDP: 0.06888080259939315
# Exchange_Rate: 0.05635124916267135
# Inflation: 0.05330768006237102
# 2015: 0.05228977926021207
# Trade_Openess: 0.051099301917708485
# Luxembourg: 0.04219273561528951
# Current_Account_Balance: 0.033671461972982764
# Yes: 0.026312702455205964
# Spain: 0.02545660650446481
# Netherlands: 0.020708982652070124
# Unemployment_Rate: 0.01990527703383628
# United States of America: 0.012219110874258716
# Germany: 0.008172378704371546
# Corporate_Tax_Rate: 0.0006324123275425061
# Venezuela, Bolivarian Republic of: 0.0
# Uruguay: 0.0
# Turkey: 0.0
# Thailand: 0.0
# Taipei, Chinese: 0.0
# Switzerland: 0.0
# Sweden: 0.0
# South Africa: 0.0
# Slovenia: 0.0
# Slovakia: 0.0
# Singapore: 0.0
# Russian Federation: 0.0
# Romania: 0.0
# Portugal: 0.0
# Population: 0.0
# Poland: 0.0
# Philippines: 0.0
# Norway: 0.0
# Nigeria: 0.0
# New Zealand: 0.0
# Morocco: 0.0
# Mexico: 0.0
# Malta: 0.0
# Malaysia: 0.0
# Long_Term_Interest_Rates: 0.0
# Lithuania: 0.0
# Latvia: 0.0
# Korea, Republic of: 0.0
# Japan: 0.0
# Italy: 0.0
# Israel: 0.0
# Iran, Islamic Republic of: 0.0
# Indonesia: 0.0
# India: 0.0
# Iceland: 0.0
# Hungary: 0.0
# Hong Kong, China: 0.0
# Greece: 0.0
# Finland: 0.0
# Estonia: 0.0
# Egypt: 0.0
# Denmark: 0.0
# Czech Republic: 0.0
# Cyprus: 0.0
# Croatia: 0.0
# Construction: 0.0
# China: 0.0
# Chile: 0.0
# Canada: 0.0
# Bulgaria: 0.0
# Brazil: 0.0
# Belgium: 0.0
# Austria: 0.0
# Australia: 0.0
# 2017: 0.0
# 2016: 0.0
# 2014: 0.0

# %% [markdown]
# # Test evaluation

# %%
# drop labels for training set, but keep all others
Xtest = model_test.drop("FDI", axis=1)
ytest = model_test["FDI"].copy()

best_model = grid_search.best_estimator_

yhat = best_model.predict(Xtest)

final_mse = mean_squared_error(ytest, yhat)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 25.452310523438594

# %% [markdown]
# # Reduction in RMSE rate

# %%
100*(baseline_rmse - final_rmse)/baseline_rmse
# Out:
# 16.05475271073603
